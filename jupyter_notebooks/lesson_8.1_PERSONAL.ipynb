# %% [markdown]
# # **Lesson_8.1**

# %% [markdown]
# Task

# %% [markdown]
# * Build and train NN to predict compressive strength using the concrete_data.csv. Optimise and assess the model via hyperparameter and model architecture optimisation. Test the model on an individual input. Calculate and discuss residuals.
